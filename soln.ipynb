# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import binary_dilation, binary_erosion, binary_hit_or_miss

from ListSelEm import *

# %%
plt.imshow(list_se_3x3[5])
plt.show()

# %%
f = open('Dataset/CatA_Simple/Task000.json')
data = json.load(f)
# print(data[0]['input'])
ip = np.array(data[0]['input'])
op = np.array(data[0]['output'])

plt.imshow(ip)
plt.show()

plt.imshow(op)
plt.show()

# %%
dil = binary_dilation(op)
plt.imshow(dil)
plt.show()
dil = binary_dilation(op, list_se_3x3[5])
plt.imshow(dil)
plt.show()
